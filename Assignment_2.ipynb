# %% [markdown]
# # Assignment 2

# %% [markdown]
# ![6th.jpg](attachment:6th.jpg)

# %% [markdown]
# ![7th.jpg](attachment:7th.jpg)

# %% [markdown]
# ![8th.jpg](attachment:8th.jpg)

# %% [markdown]
# ![9th.jpg](attachment:9th.jpg)

# %% [markdown]
# ![10th.jpg](attachment:10th.jpg)
