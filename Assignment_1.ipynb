# %% [markdown]
# # Assignment 1

# %% [markdown]
# ![1s.jpg](attachment:1s.jpg)

# %% [markdown]
# ![2n.jpg](attachment:2n.jpg)

# %% [markdown]
# ![3rd.jpg](attachment:3rd.jpg)

# %% [markdown]
# ![4t.jpg](attachment:4t.jpg)

# %% [markdown]
# ![5th.jpg](attachment:5th.jpg)
